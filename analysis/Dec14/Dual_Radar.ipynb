# %% [markdown]
# # Dual Radar Analysis #
# Ivan Arias
#
# 2021/04/07

# %%
import sys
sys.path.append('/net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot')
import dual_radar_plot as plot
import importlib
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
importlib.reload(plot)

filename_chivo_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_original_2018-12-14T0200.nc'
filename_chivo_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_att_corrected_2018-12-14T02_00.nc'

filename_csapr_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_original_2018-12-14T02_00.nc'

filename_csapr_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_att_corrected_2018-12-14T02_00.nc'

ind = 2

fig = plot.chivo_csapr_cappi_1a(filename_chivo_1a, filename_csapr_1a, 'Reflectivity', ind)
fig = plot.chivo_csapr_cappi_1a(filename_chivo_1a, filename_csapr_1a, 'Diff. Ref.', ind)

# %%
importlib.reload(plot)

ind = 1

fig = plot.dual_radar_cappi(filename_chivo_1a, filename_chivo_1b, 
                           filename_csapr_1a, filename_csapr_1b, 'Reflectivity', ind)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:119: RuntimeWarning: invalid value encountered in true_divide
#   1./radar1_att + 1./radar2_att)
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:125: UserWarning: The following kwargs were not used by contour: 'antialised'
#   plt.contour(x, y, combined_field_var[ind], levels=[30], colors=['k', 'k', 'k'], antialised = True)

# %%
importlib.reload(plot)

filename_chivo_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_original_2018-12-14T0200.nc'
filename_chivo_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_att_corrected_2018-12-14T02_00.nc'

filename_csapr_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_original_2018-12-14T02_00.nc'

filename_csapr_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_att_corrected_2018-12-14T02_00.nc'

ind = 2

fig = plot.chivo_csapr_cappi_1a(filename_chivo_1a, filename_csapr_1a, 'Reflectivity', ind)
fig = plot.chivo_csapr_cappi_1a(filename_chivo_1a, filename_csapr_1a, 'Diff. Ref.', ind)

# %%
importlib.reload(plot)

filename_chivo_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_original_2018-12-14T0200.nc'
filename_chivo_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_att_corrected_2018-12-14T02_00.nc'

filename_csapr_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_original_2018-12-14T02_00.nc'

filename_csapr_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_att_corrected_2018-12-14T02_00.nc'

ind = 0

fig = plot.chivo_csapr_cappi_1b(filename_chivo_1b, filename_csapr_1b, 'Reflectivity', ind)
fig = plot.chivo_csapr_cappi_1b(filename_chivo_1b, filename_csapr_1b, 'Diff. Ref.', ind)

# %%
ind = 0

fig = plot.cappi_1a(filename_csapr_1a, 'Reflectivity', ind, 'CHIVO')

# %%
importlib.reload(plot)

filename_chivo_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_original_2018-12-14T0200.nc'
filename_chivo_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/chivo_att_corrected_2018-12-14T02_00.nc'

filename_csapr_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_original_2018-12-14T02_00.nc'

filename_csapr_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/20181214_0200/csapr_att_corrected_2018-12-14T02_00.nc'

ind = 2

fig = plot.chivo_csapr_cappi(filename_chivo_1b, filename_csapr_1b, 'Reflectivity', ind)
fig = plot.chivo_csapr_cappi(filename_chivo_1b, filename_csapr_1b, 'Diff. Ref.', ind)

# %%
importlib.reload(plot)

filename_chivo_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/chivo_original_2018-12-14T0230.nc'
filename_chivo_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/chivo_att_corrected_2018-12-14T02_30.nc'

filename_csapr_1a = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/csapr_original_2018-12-14T02_30.nc'
filename_csapr_1b = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Dec14/grided_data/csapr_att_corrected_2018-12-14T02_30.nc'

ind = 2

fig = plot.cappi_strom_contour(filename_chivo_1a, filename_chivo_1b, 
                        filename_csapr_1a, filename_csapr_1b, ind)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:62: RuntimeWarning: divide by zero encountered in true_divide
#   att_chivo + att_csapr)
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:67: UserWarning: The following kwargs were not used by contour: 'antialised'
#   plt.contour(x, y, combined_field_var[ind], levels=[30], colors=['k', 'k', 'k'], antialised = True)

# %%
importlib.reload(plot)

ind = 1

fig = plot.chivo_csapr_cappi(filename_chivo_1b, filename_csapr_1b, 'Reflectivity', ind)
fig = plot.chivo_csapr_cappi(filename_chivo_1b, filename_csapr_1b, 'Diff. Ref.', ind)

# %%
importlib.reload(plot)

ind = 1

fig = plot.dual_radar_cappi(filename_chivo_1a, filename_chivo_1b, 
                           filename_csapr_1a, filename_csapr_1b, 'Reflectivity', ind)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:119: RuntimeWarning: invalid value encountered in true_divide
#   1./radar1_att + 1./radar2_att)
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:125: UserWarning: The following kwargs were not used by contour: 'antialised'
#   plt.contour(x, y, combined_field_var[ind], levels=[30], colors=['k', 'k', 'k'], antialised = True)

# %%
ind = 1

fig = plot.cappi_1a(filename_csapr_1a, 'Reflectivity', ind)

# %%
importlib.reload(plot)

filename_chivo_1a = 'chivo_1a_20181214_0200.nc'
filename_chivo_1b = 'chivo_1b.2_20181214_0200.nc'

filename_csapr_1a = 'csapr_b1_20181214_0200.nc'
filename_csapr_1b = 'csapr_1b.2_20181214_0200.nc'

ind = 2

fig = plot.cappi_strom_contour(filename_chivo_1a, filename_chivo_1b, 
                        filename_csapr_1a, filename_csapr_1b, ind)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:62: RuntimeWarning: divide by zero encountered in true_divide
#   att_chivo + att_csapr)
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:67: UserWarning: The following kwargs were not used by contour: 'antialised'
#   plt.contour(x, y, combined_field_var[ind], levels=[30], colors=['k', 'k', 'k'], antialised = True)

# %%
importlib.reload(plot)

filename_chivo = 'chivo_1a_20181214_0200.nc'
'chivo_1a_20181214_0230.nc'
filename_csapr = 'csapr_b1_20181214_0200.nc'
'csapr_b1_20181214_0230.nc'

ind = 2

fig = plot.cappi_1a(filename_csapr, 'Reflectivity', ind)

# %%
importlib.reload(plot)

filename_chivo_1a = 'chivo_1a_20181214_0230.nc'
filename_chivo_1b = 'chivo_1b_test_20181214_0230.nc'

filename_csapr_1a = 'csapr_b1_20181214_0230.nc'
filename_csapr_1b = 'csapr_1b_test_20181214_0230.nc'

ind = 2

fig = plot.cappi_strom_contour(filename_chivo_1a, filename_chivo_1b, 
                        filename_csapr_1a, filename_csapr_1b, ind)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:62: RuntimeWarning: divide by zero encountered in true_divide
#   plt.text(0, 0, ' C', fontsize=12)
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:67: UserWarning: The following kwargs were not used by contour: 'antialised'
#   # plt.plot(-10, 20, 'ok', markersize=5)

# %%
importlib.reload(plot)

radar1_filename_1a = 'chivo_1a_20181214_0230.nc'
radar1_filename_1b = 'chivo_1b_test_20181214_0230.nc'

radar2_filename_1a = 'csapr_b1_20181214_0230.nc'
radar2_filename_1b = 'csapr_1b_test_20181214_0230.nc'

ind = 2

fig = plot.dual_radar_cappi(radar1_filename_1a, radar1_filename_1b, 
                           radar2_filename_1a, radar2_filename_1b, 'Reflectivity', ind)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:119: RuntimeWarning: invalid value encountered in true_divide
#   elif 'REF' in field.upper() and 'DIF' in field.upper():
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/dual_radar_plot.py:125: UserWarning: The following kwargs were not used by contour: 'antialised'
#   radar1_att = radar1_field_var_1b[ind] - radar1_field_var_1a

# %%
importlib.reload(plot)

filename_1a = 'csapr_b1_20181214_0230.nc'
filename_1b = 'csapr_1b_test_20181214_0230.nc'

filename_1a = 'chivo_1a_20181214_0230.nc'
filename_1b = 'chivo_1b_test_20181214_0230.nc'

ind = 3

fig = plot.cappi_att(filename_1a, filename_1b, 'Reflectivity', ind)

# %%
importlib.reload(plot)

filename_chivo = 'chivo_1b_test_20181214_0230.nc'
'chivo_1b.2_20181214_0230.nc'
filename_csapr = 'csapr_1b_test_20181214_0230.nc'
'csapr_drops_20181214_0230.nc'

ind = 3

fig = plot.cappi(filename_csapr, 'Reflectivity', ind)

# %%
importlib.reload(plot)

filename_chivo = 'chivo_1b_20181214_0230.nc'
filename_csapr = 'csapr_drops_20181214_0230.nc'

ind = 3

fig = plot.chivo_csapr_cappi(filename_chivo, filename_csapr, 'Reflectivity', ind)
fig = plot.chivo_csapr_cappi(filename_chivo, filename_csapr, 'Diff. Ref.', ind)

# %%
# Create grid chivo

import pyart
import time
import matplotlib.pyplot as plt

def grid_radar(radar, grid_shape=(20, 301, 301), xlim=(-150000, 150000),
               ylim=(-150000, 150000), zlim=(1000, 20000),
               fields=['DT', 'VT'], origin=None):
    bt = time.time()
    radar_list = [radar]
    if origin is None:
        origin = (radar.latitude['data'][0],
                  radar.longitude['data'][0])
    grid = pyart.map.grid_from_radars(
        radar_list, grid_shape=grid_shape,
        grid_limits=(zlim, ylim, xlim),
        grid_origin=origin, fields=fields,
        gridding_algo='map_gates_to_grid', grid_origin_alt=0.0)
    print(time.time()-bt, 'seconds to grid radar')
    return grid


filename_chivo = '/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1a/2018/12/14/chivo.1a.20181214_020047.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1a/2018/12/14/chivo.1a.20181214_023049.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_023042.REL_PNL360A.nc'

filename_csapr = '/net/k2/storage/projects/CSAPR/DOE_b1/corcsapr2cfrppiqcM1.b1.20181214.020004.nc'

'/net/k2/storage/projects/CSAPR/DROPS/corcsapr2cfrppiqcM1.b1.20181214.023003.nc'

chivo = pyart.io.read(filename_chivo)
csapr = pyart.io.read(filename_csapr)

g = grid_radar(csapr, origin=(chivo.latitude['data'][0], chivo.longitude['data'][0]),
                xlim=(-100000, 50000), ylim=(-100000, 50000), grid_shape=(20, 151, 151),
                fields = ['copol_correlation_coeff', 'differential_phase', 
                          'differential_reflectivity', 'reflectivity', 'specific_differential_phase'])
                    
                        #'cross_correlation_ratio'

pyart.io.write_grid('csapr_b1_20181214_0200.nc', g)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pyart/map/gates_to_grid.py:162: DeprecationWarning: Barnes weighting function is deprecated. Please use Barnes 2 to be consistent with Pauley and Wu 1990.
#   " Pauley and Wu 1990.", DeprecationWarning)
# 6.622466802597046 seconds to grid radar

# %%
# Create grid CSAPR

import pyart
import time
import matplotlib.pyplot as plt

def grid_radar(radar, grid_shape=(20, 301, 301), xlim=(-150000, 150000),
               ylim=(-150000, 150000), zlim=(1000, 20000),
               fields=['DT', 'VT'], origin=None):
    bt = time.time()
    radar_list = [radar]
    if origin is None:
        origin = (radar.latitude['data'][0],
                  radar.longitude['data'][0])
    grid = pyart.map.grid_from_radars(
        radar_list, grid_shape=grid_shape,
        grid_limits=(zlim, ylim, xlim),
        grid_origin=origin, fields=fields,
        gridding_algo='map_gates_to_grid', grid_origin_alt=0.0)
    print(time.time()-bt, 'seconds to grid radar')
    return grid


filename_chivo = '/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1a/2018/12/14/chivo.1a.20181214_023049.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_023042.REL_PNL360A.nc'

filename_csapr = '/net/k2/storage/projects/CSAPR/DOE_b1/corcsapr2cfrppiqcM1.b1.20181214.023003.nc'

'/net/k2/storage/projects/CSAPR/DROPS/corcsapr2cfrppiqcM1.b1.20181214.023003.nc'

chivo = pyart.io.read(filename_chivo)
csapr = pyart.io.read(filename_csapr)

g = grid_radar(csapr, origin=(chivo.latitude['data'][0], chivo.longitude['data'][0]),
                xlim=(-100000, 50000), ylim=(-100000, 50000), grid_shape=(20, 151, 151),
                fields = ['normalized_coherent_power', 'differential_phase', 
                          'differential_reflectivity', 'reflectivity', 'specific_differential_phase'])

pyart.io.write_grid('csapr_b1_20181214_0230.nc', g)
