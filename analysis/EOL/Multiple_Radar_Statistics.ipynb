# %% [markdown]
# # Multiple Radar Statistics #
# Ivan Arias
#
# 2021/09/27

# %% [markdown]
# ## Grid test##

# %%
import sys
sys.path.append('/net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot')
import chivo_grid_utl as utl
import dual_radar_plot as plot
import chivo_plot as chivo_plot
import pyart
import glob
import netCDF4
import numpy as np
from operator import and_
import multiprocessing as mp
import gc
import os
import importlib

# %%
importlib.reload(utl)

filename = '/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_023014.REL_HYDRO360.nc' 

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_023049.REL_PNL360A.nc'

radar = pyart.io.read(filename)
grid = utl.grid_hail(radar)

# %%
importlib.reload(utl)

filename = '/net/k2/storage/projects/CSAPR/level_1b.2/corcsapr2cfrppiqcM1.1b.20181214.023003.nc'

'/net/k2/storage/people/idariash/home/Field_Campaigns/Relampago/Analisis/Dec_14/CSAPR/level_1b/test/corcsapr2cfrppiqcM1.1b.20181214.020004.nc'

'/net/k2/storage/people/idariash/home/Field_Campaigns/Relampago/Analisis/Dec_14/CSAPR/level_1b/corcsapr2cfrppiqcM1.1b.20181214.020004.nc'

'/net/k2/storage/projects/CSAPR/DROPS/corcsapr2cfrppiqcM1.b1.20181214.030003.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_030013.REL_HYDRO360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_024010.REL_HYDRO360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_023014.REL_HYDRO360.nc' 

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_023049.REL_PNL360A.nc'

radar = pyart.io.read(filename)
grid = utl.grid_hail_oneSweep(radar)

# %%
importlib.reload(plot)

ind = 0

fig = plot.cappi_grid(grid, 'hydroclass' ,ind)

# %%
importlib.reload(chivo_plot)

sweep = 0

fig = chivo_plot.ppi_drops_1b(filename, sweep, 'CHIVO')

# %%
importlib.reload(plot)

ind = 4

fig = plot.cappi_grid(grid, 'rain' ,ind)

# %%
importlib.reload(plot)

ind = 6

fig = plot.cappi_grid(grid, 'REF' ,ind)
