# %%
# CHIVO noDROPS RHI

import sys
sys.path.append('/net/denali/storage2/radar2/tmp/Ivan/CSU/RELAMPAGO/plot')
import chivo_plot as plot
import importlib
importlib.reload(plot)

filename = '/net/denali/storage/radar/RELAMPAGO/RAW/2019/01/25/COL20190125_194420'
fig = plot.chivo_rhi(filename, 11, 80)

# %%
# CHIVO DROPS RHI

import sys
sys.path.append('/net/denali/storage2/radar2/tmp/Ivan/CSU/RELAMPAGO/plot')
import chivo_plot as plot
import importlib
importlib.reload(plot)

filename = '/net/denali/storage/radar/RELAMPAGO/DROPS/2019/01/25/cfrad.20190125_210858.592_to_20190125_211009.717_col-radar_REL_RHI30_RHI.nc' 
#filename = '/net/denali/storage/radar/RELAMPAGO/DROPS/2019/01/25/cfrad.20190125_211714.848_to_20190125_211916.011_col-radar_REL_RHI30_RHI.nc'
fig = plot.chivo_rhi_drops(filename, 2)
# Out:
# check line 385 at /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.6/site-packages/pyart/core/radar.py

# %%
# CSAPR noDROPS RHI

import sys
sys.path.append('/net/denali/storage2/radar2/tmp/Ivan/CSU/RELAMPAGO/plot')
import chivo_plot as plot
import importlib
importlib.reload(plot)

filename = '/net/denali/storage2/radar2/tmp/Ivan/DOE/RELAMPAGO/CSAPR_RHI/corcsapr2cfrhsrhiM1.a1.20190125.195215.nc'
fig = plot.csapr_rhi(filename, 1, 80)

# %%
# CSAPR DROPS

import sys
sys.path.append('/net/denali/storage2/radar2/tmp/Ivan/CSU/RELAMPAGO/plot')
import chivo_plot as plot
import importlib
importlib.reload(plot)

filename = '/net/denali/storage2/radar2/tmp/Ivan/DOE/RELAMPAGO/DROPS_RHI/corcsapr2cfrhsrhiM1.a1.20190125.195215.nc'
fig = plot.csapr_rhi_drops(filename, 1, 80)
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-d6ceb695a9e0> in <module>
#       8
#       9 filename = '/net/denali/storage2/radar2/tmp/Ivan/DOE/RELAMPAGO/DROPS_RHI/corcsapr2cfrhsrhiM1.a1.20190125.195215.nc'
# ---> 10 fig = plot.csapr_rhi_drops(filename, 1, 80)
#
# /net/denali/storage2/radar2/tmp/Ivan/CSU/RELAMPAGO/plot/chivo_plot.py in csapr_rhi_drops(filename, sweep, xlim)
#     701                     vmin = -15, vmax = 80, mask_outside = False,
#     702                     cmap = pyart.graph.cm.NWSRef, colorbar_label =  'Corrected Reflectivity (dBZ)',
# --> 703                     gatefilter = gatefilter)
#     704     display.set_limits(ylim=[0, 21])
#     705     display.set_limits(xlim=[0, xlim])
#
# ~/anaconda3/lib/python3.6/site-packages/pyart/graph/radardisplay.py in plot_rhi(self, field, sweep, mask_tuple, vmin, vmax, norm, cmap, mask_outside, title, title_flag, axislabels, axislabels_flag, reverse_xaxis, colorbar_flag, colorbar_label, colorbar_orient, edges, gatefilter, filter_transitions, ax, fig, ticks, ticklabs, raster, title_datetime_format, title_use_sweep_time, **kwargs)
#     474         # get data for the plot
#     475         data = self._get_data(
# --> 476             field, sweep, mask_tuple, filter_transitions, gatefilter)
#     477         x, y, z = self._get_x_y_z(sweep, edges, filter_transitions)
#     478
#
# ~/anaconda3/lib/python3.6/site-packages/pyart/graph/radardisplay.py in _get_data(self, field, sweep, mask_tuple, filter_transitions, gatefilter)
#    1291                   gatefilter):
#    1292         """ Retrieve and return data from a plot function. """
# -> 1293         sweep_slice = self._radar.get_slice(sweep)
#    1294         data = self.fields[field]['data'][sweep_slice]
#    1295
#
# ~/anaconda3/lib/python3.6/site-packages/pyart/core/radar.py in get_slice(self, sweep)
#     383         """ Return a slice for selecting rays for a given sweep. """
#     384         #start, end = self.get_start_end(sweep)
# --> 385         end = end - 15 # Use this line when DROP data, comment this line otherwise
#     386
#     387         return slice(start, end+1)
#
# UnboundLocalError: local variable 'end' referenced before assignment
