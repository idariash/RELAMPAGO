# %% [markdown]
# # AMS Mountan 2020 / Plots with terrain #
# Ivan Arias
#
# 2020/07/01

# %%
import pyart
import time

import AMS_Mountain_utl as utl
import importlib

from mpl_toolkits.basemap import Basemap, shiftgrid, cm
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
import netCDF4

import scipy.ndimage as spyi

# %%
# Read topography, pasar para abajo

topo_filename = 'terr.nc'
topography = Dataset(topo_filename)

lons = topography.variables['X'][:]
lats = topography.variables['Y'][:]
terr = 0.001*topography.variables['topo'][:]

# %%
# Create grid

importlib.reload(utl)

# CHIVO level 1b, old files denali
'/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_011043.REL_PFAR360.nc'
'/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_012041.REL_PFAR360.nc'
'/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_013042.REL_PFAR360.nc'
'/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_014042.REL_PFAR360.nc'
'/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_015043.REL_PFAR360.nc'
'/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_020041.REL_PFAR360.nc'
'/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_021042.REL_PNL360A.nc'

# New files from k2

chivo_filename = '/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_000046.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_001055.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_002056.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_003044.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_004058.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_005043.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_010047.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_011056.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_012043.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_013054.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_014059.REL_PFAR360.nc'


'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_015054.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_020047.REL_PFAR360.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_021057.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_022100.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_023049.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_024046.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_025057.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_030048.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_031048.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_032050.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_033105.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_034100.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_035048.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_040051.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_041046.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_042047.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_043043.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_044055.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_045049.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_050049.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_051047.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_052048.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_053048.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_054045.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_055050.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_060050.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_061049.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_062051.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_063051.REL_PNL360A.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_064015.COWHA_FARA.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_065020.COWHA_FARA.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_070008.COWHA_FARA.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_071013.COWHA_FARA.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_072018.COWHA_FARA.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_073006.COWHA_FARA.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_074011.COWHA_FARA.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_075016.COWHA_FARA.nc'

chivo_filename = '/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_080004.COWHA_FARA.nc'

chivo = pyart.io.read(chivo_filename)
chivo_grid = utl.grid_radar(chivo, origin=(chivo.latitude['data'][0], chivo.longitude['data'][0]))

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y%m%dT%H%M')

chivo_grid_fname = ('chivo_grid_'+ time_text + '.nc')
chivo_grid.write(chivo_grid_fname)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pyart/map/gates_to_grid.py:162: DeprecationWarning: Barnes weighting function is deprecated. Please use Barnes 2 to be consistent with Pauley and Wu 1990.
#   " Pauley and Wu 1990.", DeprecationWarning)

# %%
# Plot PPI over map

filename = 'chivo_grid_20181214T0800.nc'
#filename = 'csapr_grid_20181214T01.nc'
height_toCut = 1.0
reflectivity_toCut = 20
range_toCut = 150
chivo_grid = pyart.io.read_grid(filename)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']

delta = 4#deg
lats_mask = np.absolute(lats - lat_0) < delta

#(lat_0 - delta < lats) & (lats < lat_0 + 1)
lons_mask = np.absolute(lons - lon_0) < delta
#(lon_0 - delta < lons) & (lons < lon_0 + 1)  

Sierras_terr = terr[lats_mask, :]
Sierras_terr = Sierras_terr[:, lons_mask]
Sierras_terr = np.ma.masked_where( Sierras_terr < 0.5, Sierras_terr)

Sierras_lons = lons[lons_mask]
Sierras_lats = lats[lats_mask]

Sierras_lons_grid, Sierras_lats_grid = np.meshgrid(Sierras_lons, Sierras_lats)

Sierras_terr = spyi.gaussian_filter(Sierras_terr, sigma = 2)



fig = plt.figure(figsize=(6, 5))



m = Basemap(projection='lcc', resolution=None,
            width=300E3, height=300E3, 
            lat_0=lat_0, lon_0=lon_0)

#m.etopo(scale=2, alpha=0.5)

parallels = np.arange(-40,-20,0.5)
# labels = [left,right,top,bottom]
m.drawparallels(parallels,labels=[True,False,False, False])

meridians = np.arange(-70,-60.,0.5)
m.drawmeridians(meridians,labels=[True,False,False,True])

x_Cordoba, y_Cordoba = m(-64.19, -31.42)
x_CHIVO, y_CHIVO = m(-64.1686, -31.6342)
x_ARM, y_ARM = m(-64.7284, -32.1264)
x_Rio4to, y_Rio4to = m(-64.3493, -33.1232)

plt.plot(x_CHIVO, y_CHIVO, 'ok', markersize=5)
plt.text(x_CHIVO, y_CHIVO, ' C', fontsize=12);
                                       
plt.plot(x_ARM, y_ARM, 'ok', markersize=5)
plt.text(x_ARM, y_ARM, ' Y', fontsize=12);
                                       
#levels_terr = [0.5, 1.5]
levels_terr = [1, 2]

m.contour(Sierras_lons_grid, Sierras_lats_grid, Sierras_terr, levels_terr, 
               latlon = True, linewidths = 1, colors = 'k',
                      linestyles='solid', antialiased=True, animated=True)

Z = chivo_grid.fields['corrected_reflectivity']['data']

x, y, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.y['data'],
                     0.001*chivo_grid.z['data'])

x = np.swapaxes(x,1,2)
x = np.swapaxes(x,0,1)

y = np.swapaxes(y,1,2)
y = np.swapaxes(y,0,1)

z = np.swapaxes(z,1,2)
z = np.swapaxes(z,0,1)

R = np.sqrt(x ** 2 + y ** 2 + z ** 2)

Z = np.ma.masked_where( z < height_toCut, Z)
Z = np.ma.masked_where( R > range_toCut, Z)

Z_max = np.amax(Z, axis=0)
Z_max = np.ma.masked_where( Z_max < reflectivity_toCut, Z_max)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']
chivo_lons, chivo_lats = chivo_grid.get_point_longitude_latitude()


cs = m.pcolormesh(chivo_lons, chivo_lats, Z_max, vmin=0, vmax=70, latlon=True,
             cmap='pyart_NWSRef')

m.colorbar(cs, label='Reflectivity (dBZ)')

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y-%m-%dT%H:%M UTC')


plt.title('CSU-CHIVO | '+ time_text+ ' \n Max. Reflectivity')

time_text = time_start.strftime('%Y%m%dT%H%M')
fig_name = ('./fig/sur_maxRef_' + time_text + '.png')
fig.savefig(fig_name)

#---------------------------------------------------------

Z = chivo_grid.fields['corrected_reflectivity']['data']

Z = np.ma.masked_where( Z < reflectivity_toCut, Z)

x, y, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.y['data'],
                     0.001*chivo_grid.z['data'])

x = np.swapaxes(x,1,2)
x = np.swapaxes(x,0,1)

y = np.swapaxes(y,1,2)
y = np.swapaxes(y,0,1)

z = np.swapaxes(z,1,2)
z = np.swapaxes(z,0,1)

R = np.sqrt(x ** 2 + y ** 2 + z ** 2)

Z = np.ma.masked_where( z < height_toCut, Z)
Z = np.ma.masked_where( R > range_toCut, Z)


#Zdr_max = np.ma.masked_where( Z_max < 20, Zdr_max)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']
chivo_lons, chivo_lats = chivo_grid.get_point_longitude_latitude()

x, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.z['data'])

Z = np.swapaxes(Z,0,1)

Z_max = np.amax(Z, axis=0)
lons_vector = np.mean(chivo_lons, axis=0)
lons_mat, z = np.meshgrid(lons_vector, 0.001*chivo_grid.z['data'])

fig = plt.figure(figsize=(7, 3))
cs = plt.pcolormesh(lons_mat, z, Z_max, vmin=0, vmax=70,# latlon=True,
             cmap='pyart_NWSRef')

plt.colorbar(cs, label='Reflectivity [dBZ]')

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y-%m-%dT%H:%M UTC')

plt.title('CSU-CHIVO | '+ time_text+ ' \n Max. Reflectivity')

plt.xlim(-65.8, -62.8)
plt.ylim(0, 20)

plt.xlabel('Longitude (°)')
plt.ylabel('Hieght (km)')

time_text = time_start.strftime('%Y%m%dT%H%M')
fig_name = ('./fig/lon_maxRef_' + time_text + '.png')
fig.savefig(fig_name)

#---------------------------------------------------

Z = chivo_grid.fields['corrected_reflectivity']['data']
Zdr = chivo_grid.fields['corrected_differential_reflectivity']['data']

Zdr = np.ma.masked_where( Z < reflectivity_toCut, Zdr)

x, y, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.y['data'],
                     0.001*chivo_grid.z['data'])

x = np.swapaxes(x,1,2)
x = np.swapaxes(x,0,1)

y = np.swapaxes(y,1,2)
y = np.swapaxes(y,0,1)

z = np.swapaxes(z,1,2)
z = np.swapaxes(z,0,1)

R = np.sqrt(x ** 2 + y ** 2 + z ** 2)

Zdr = np.ma.masked_where( z < height_toCut, Zdr)
Zdr = np.ma.masked_where( R > range_toCut, Zdr)


#Zdr_max = np.ma.masked_where( Z_max < 20, Zdr_max)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']
chivo_lons, chivo_lats = chivo_grid.get_point_longitude_latitude()

Zdr = np.swapaxes(Zdr,0,1)

Zdr_max = np.mean(Zdr, axis=0)
lons_vector = np.mean(chivo_lons, axis=0)
lons_mat, z = np.meshgrid(lons_vector, 0.001*chivo_grid.z['data'])

fig = plt.figure(figsize=(7, 3))
cs = plt.pcolormesh(lons_mat, z, Zdr_max, vmin=-2, vmax=6,# latlon=True,
             cmap=pyart.graph.cm.RefDiff)

plt.colorbar(cs, label='Diff. Reflectivity [dB]')

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y-%m-%dT%H:%M UTC')

plt.title('CSU-CHIVO | '+ time_text+ ' \n Mean Diff. Reflectivity')

plt.xlim(-65.8, -62.8)
plt.ylim(0, 20)

plt.xlabel('Longitude (°)')
plt.ylabel('Hieght (km)')

time_text = time_start.strftime('%Y%m%dT%H%M')
fig_name = ('./fig/lon_meanDiffRef_' + time_text + '.png')
fig.savefig(fig_name)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: UserWarning: The following kwargs were not used by contour: 'animated'

# %%
# Plot PPI over map

filename = 'chivo_grid_20181214T0200.nc'
#filename = 'csapr_grid_20181214T01.nc'
height_toCut = 1.0
reflectivity_toCut = 20
range_toCut = 70
chivo_grid = pyart.io.read_grid(filename)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']

delta = 4#deg
lats_mask = np.absolute(lats - lat_0) < delta

#(lat_0 - delta < lats) & (lats < lat_0 + 1)
lons_mask = np.absolute(lons - lon_0) < delta
#(lon_0 - delta < lons) & (lons < lon_0 + 1)  

Sierras_terr = terr[lats_mask, :]
Sierras_terr = Sierras_terr[:, lons_mask]
Sierras_terr = np.ma.masked_where( Sierras_terr < 0.5, Sierras_terr)

Sierras_lons = lons[lons_mask]
Sierras_lats = lats[lats_mask]

Sierras_lons_grid, Sierras_lats_grid = np.meshgrid(Sierras_lons, Sierras_lats)

Sierras_terr = spyi.gaussian_filter(Sierras_terr, sigma = 2)



fig = plt.figure(figsize=(6, 5))



m = Basemap(projection='lcc', resolution=None,
            width=200E3, height=200E3, 
            lat_0=lat_0, lon_0=lon_0)

m.etopo(scale=2, alpha=0.5)

parallels = np.arange(-40,-20,0.5)
# labels = [left,right,top,bottom]
m.drawparallels(parallels,labels=[True,False,False, False])

meridians = np.arange(-70,-60.,0.5)
m.drawmeridians(meridians,labels=[True,False,False,True])

x_Cordoba, y_Cordoba = m(-64.19, -31.42)
x_CHIVO, y_CHIVO = m(-64.1686, -31.6342)
x_ARM, y_ARM = m(-64.7284, -32.1264)
x_Rio4to, y_Rio4to = m(-64.3493, -33.1232)

plt.plot(x_CHIVO, y_CHIVO, 'ok', markersize=5)
plt.text(x_CHIVO, y_CHIVO, ' C', fontsize=12);
                                       
plt.plot(x_ARM, y_ARM, 'ok', markersize=5)
plt.text(x_ARM, y_ARM, ' Y', fontsize=12);
                                       
levels_terr = [0.5, 1.5]

m.contour(Sierras_lons_grid, Sierras_lats_grid, Sierras_terr, levels_terr, 
               latlon = True, linewidths = 1, colors = 'k',
                      linestyles='solid', antialiased=True, animated=True)

Z = chivo_grid.fields['corrected_reflectivity']['data']

x, y, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.y['data'],
                     0.001*chivo_grid.z['data'])

x = np.swapaxes(x,1,2)
x = np.swapaxes(x,0,1)

y = np.swapaxes(y,1,2)
y = np.swapaxes(y,0,1)

z = np.swapaxes(z,1,2)
z = np.swapaxes(z,0,1)

R = np.sqrt(x ** 2 + y ** 2 + z ** 2)

Z = np.ma.masked_where( z < height_toCut, Z)
Z = np.ma.masked_where( R > range_toCut, Z)

Z_max = np.amax(Z, axis=0)
Z_max = np.ma.masked_where( Z_max < reflectivity_toCut, Z_max)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']
chivo_lons, chivo_lats = chivo_grid.get_point_longitude_latitude()


cs = m.pcolormesh(chivo_lons, chivo_lats, Z_max, vmin=0, vmax=70, latlon=True,
             cmap='pyart_NWSRef')

m.colorbar(cs, label='Reflectivity [dBZ]')

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y-%m-%dT%H:%M UTC')


plt.title('CSU-CHIVO | '+ time_text+ ' \n Max. Reflectivity')

time_text = time_start.strftime('%Y%m%dT%H%M')
fig_name = ('./fig/sur_maxRef_' + time_text + '.png')
fig.savefig(fig_name)

#---------------------------------------------------------

Z = chivo_grid.fields['corrected_reflectivity']['data']

Z = np.ma.masked_where( Z < reflectivity_toCut, Z)

x, y, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.y['data'],
                     0.001*chivo_grid.z['data'])

x = np.swapaxes(x,1,2)
x = np.swapaxes(x,0,1)

y = np.swapaxes(y,1,2)
y = np.swapaxes(y,0,1)

z = np.swapaxes(z,1,2)
z = np.swapaxes(z,0,1)

R = np.sqrt(x ** 2 + y ** 2 + z ** 2)

Z = np.ma.masked_where( z < height_toCut, Z)
Z = np.ma.masked_where( R > range_toCut, Z)


#Zdr_max = np.ma.masked_where( Z_max < 20, Zdr_max)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']
chivo_lons, chivo_lats = chivo_grid.get_point_longitude_latitude()

x, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.z['data'])

Z = np.swapaxes(Z,0,1)

Z_max = np.amax(Z, axis=0)
lons_vector = np.mean(chivo_lons, axis=0)
lons_mat, z = np.meshgrid(lons_vector, 0.001*chivo_grid.z['data'])

fig = plt.figure(figsize=(7, 3))
cs = plt.pcolormesh(lons_mat, z, Z_max, vmin=0, vmax=70,# latlon=True,
             cmap='pyart_NWSRef')

plt.colorbar(cs, label='Reflectivity [dBZ]')

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y-%m-%dT%H:%M UTC')

plt.title('CSU-CHIVO | '+ time_text+ ' \n Max. Reflectivity')

plt.xlim(-65, -63.5)
plt.ylim(0, 20)

plt.xlabel('Longitude [°]')
plt.ylabel('Hieght [km]')

time_text = time_start.strftime('%Y%m%dT%H%M')
fig_name = ('./fig/lon_maxRef_' + time_text + '.png')
fig.savefig(fig_name)

#---------------------------------------------------

Z = chivo_grid.fields['corrected_reflectivity']['data']
Zdr = chivo_grid.fields['corrected_differential_reflectivity']['data']

Zdr = np.ma.masked_where( Z < reflectivity_toCut, Zdr)

x, y, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.y['data'],
                     0.001*chivo_grid.z['data'])

x = np.swapaxes(x,1,2)
x = np.swapaxes(x,0,1)

y = np.swapaxes(y,1,2)
y = np.swapaxes(y,0,1)

z = np.swapaxes(z,1,2)
z = np.swapaxes(z,0,1)

R = np.sqrt(x ** 2 + y ** 2 + z ** 2)

Zdr = np.ma.masked_where( z < height_toCut, Zdr)
Zdr = np.ma.masked_where( R > range_toCut, Zdr)


#Zdr_max = np.ma.masked_where( Z_max < 20, Zdr_max)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']
chivo_lons, chivo_lats = chivo_grid.get_point_longitude_latitude()

Zdr = np.swapaxes(Zdr,0,1)

Zdr_max = np.mean(Zdr, axis=0)
lons_vector = np.mean(chivo_lons, axis=0)
lons_mat, z = np.meshgrid(lons_vector, 0.001*chivo_grid.z['data'])

fig = plt.figure(figsize=(7, 3))
cs = plt.pcolormesh(lons_mat, z, Zdr_max, vmin=-2, vmax=6,# latlon=True,
             cmap=pyart.graph.cm.RefDiff)

plt.colorbar(cs, label='Diff. Reflectivity [dB]')

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y-%m-%dT%H:%M UTC')

plt.title('CSU-CHIVO | '+ time_text+ ' \n Mean Diff. Reflectivity')

plt.xlim(-65, -63.5)
plt.ylim(0, 20)

plt.xlabel('Longitude [°]')
plt.ylabel('Hieght [km]')

time_text = time_start.strftime('%Y%m%dT%H%M')
fig_name = ('./fig/lon_meanDiffRef_' + time_text + '.png')
fig.savefig(fig_name)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:65: UserWarning: The following kwargs were not used by contour: 'animated'

# %%
Z = chivo_grid.fields['corrected_reflectivity']['data']

Z = np.ma.masked_where( Z < reflectivity_toCut, Z)

x, y, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.y['data'],
                     0.001*chivo_grid.z['data'])

x = np.swapaxes(x,1,2)
x = np.swapaxes(x,0,1)

y = np.swapaxes(y,1,2)
y = np.swapaxes(y,0,1)

z = np.swapaxes(z,1,2)
z = np.swapaxes(z,0,1)

R = np.sqrt(x ** 2 + y ** 2 + z ** 2)

Z = np.ma.masked_where( z < height_toCut, Z)
Z = np.ma.masked_where( R > range_toCut, Z)


#Zdr_max = np.ma.masked_where( Z_max < 20, Zdr_max)

lon_0 = chivo_grid.origin_longitude['data']
lat_0 = chivo_grid.origin_latitude['data']
chivo_lons, chivo_lats = chivo_grid.get_point_longitude_latitude()

x, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.z['data'])

#Z = np.swapaxes(Z,1,2) # comment for x
Z = np.swapaxes(Z,0,1)

Z_max = np.amax(Z, axis=0)
lons_vector = np.mean(chivo_lons, axis=0)
lons_mat, z = np.meshgrid(0.001*chivo_grid.x['data'], 0.001*chivo_grid.z['data'])

fig = plt.figure(figsize=(7, 3))
cs = plt.pcolormesh(lons_mat, z, Z_max, vmin=0, vmax=70,# latlon=True,
             cmap='pyart_NWSRef')

plt.colorbar(cs, label='Reflectivity [dBZ]')

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y-%m-%dT%H:%M UTC')

plt.title('CSU-CHIVO | '+ time_text+ ' \n Max. Reflectivity')

plt.xlim(-80, 80)
plt.ylim(0, 20)

plt.xlabel('Longitude [°]')
plt.ylabel('Hieght [km]')

time_text = time_start.strftime('%Y%m%dT%H%M')
fig_name = ('./fig/lon_maxRef_' + time_text + '.png')
fig.savefig(fig_name)
