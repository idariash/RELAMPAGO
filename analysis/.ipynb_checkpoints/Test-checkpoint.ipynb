# %%
import pyart
import datetime
import netCDF4

filename = '/net/denali/storage/radar/RELAMPAGO/DROPS/2018/12/14/cfrad.20181214_014605.932_to_20181214_014920.266_col-radar_REL_RHI45_RHI.nc'

radar = pyart.io.read(filename)
time_start = netCDF4.num2date(radar.time['data'][0], radar.time['units'])
time_text = time_start.isoformat()

# %% [markdown]
# The following test is for parallel computing

# %%
import sys
sys.path.append('/net/denali/storage2/radar2/tmp/Ivan/CSU/RELAMPAGO/src')

import radar_climatology as climatology
import os
import datetime
import netCDF4

import importlib
importlib.reload(climatology)

import glob
from pandas import DataFrame
import pyart

import multiprocessing as mp

def radar_statistics(file):
    radar = pyart.io.read(file)
    time_start = netCDF4.num2date(radar.time['data'][0], radar.time['units'])
    time_UTC = time_start.isoformat()
    try:
#         echo_top = climatology.echo_top_drops(file)
#         max_ref = climatology.max_reflectivity_drops(file)
#         max_Kdp = climatology.max_Kdp_drops(file)
#         max_Zdr = climatology.max_Zdr_drops(file)   
        min_Zdr = climatology.min_Zdr_drops(file)
    except:
#         echo_top = -1
#         max_ref = -100
#         max_Kdp = -100
#         max_Zdr = -100   
        min_Zdr = 100
    print(time_UTC)
    return (min_Zdr)
    
pool = mp.Pool(30)
path = '/net/denali/storage/radar/RELAMPAGO/DROPS/'
files = [f for f in glob.glob(path + "**/*RHI*.nc", recursive=True)]
files.sort()
min_Zdr = []

results = [pool.apply(radar_statistics, args= file) for file in files]
# Out:
# Process ForkPoolWorker-255:
# Process ForkPoolWorker-246:
# Process ForkPoolWorker-258:
# Process ForkPoolWorker-259:
# Process ForkPoolWorker-248:
# Process ForkPoolWorker-270:
# Process ForkPoolWorker-262:
# Process ForkPoolWorker-265:
# Process ForkPoolWorker-261:
# Process ForkPoolWorker-252:
# Process ForkPoolWorker-268:
# Process ForkPoolWorker-254:
# Process ForkPoolWorker-251:
# Process ForkPoolWorker-250:
# Process ForkPoolWorker-247:
# Process ForkPoolWorker-249:
# Process ForkPoolWorker-244:
# Process ForkPoolWorker-267:
# Process ForkPoolWorker-253:
# Process ForkPoolWorker-269:
# Process ForkPoolWorker-264:
# Process ForkPoolWorker-263:
# Process ForkPoolWorker-245:
# Process ForkPoolWorker-241:
# Process ForkPoolWorker-256:
# Process ForkPoolWorker-242:
# Process ForkPoolWorker-243:
# Process ForkPoolWorker-257:
# Process ForkPoolWorker-266:
# Process ForkPoolWorker-260:
# Traceback (most recent call last):
# Traceback (most recent call last):
# ...

# %%
pool.close()

# %%
file = '/net/denali/storage/radar/RELAMPAGO/DROPS/2018/11/10/cfrad.20181110_210837.262_to_20181110_211109.213_col-radar_REL_RHI45_RHI.nc'
results = radar_statistics(file)
# Out:
# 2018-11-10T21:08:59

# %%
results
# Out:
# ('2018-11-10T21:08:59', 16.589, 67.916374, 7.3461227, 7.2607, -6.3462934)
