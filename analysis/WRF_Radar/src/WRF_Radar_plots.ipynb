# %%
import sys
sys.path.append('/net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot')

import pyart
import time

import chivo_grid_utl as utl
import importlib

from mpl_toolkits.basemap import Basemap, shiftgrid, cm
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
import netCDF4

import scipy.ndimage as spyi

# %%
importlib.reload(utl)

table_filename = '/net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Climatology/relampago_echoTop_distribution_100km_ppi_trayectories.xlsx'
radar_grid_filename = '/net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/Mountain/chivo_grid_20181214T0130.nc'
topo_filename = '/net/denali/storage2/radar2/people/idariash/home/CSU/RELAMPAGO/analysis/Mountain/terr.nc'

fig = utl.plot_grid_echoTop(table_filename, radar_grid_filename, topo_filename)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/chivo_grid_utl.py:112: UserWarning: The following kwargs were not used by contour: 'animated'
#   linestyles='solid', antialiased=True, animated=True)

# %%
importlib.reload(utl)

topo_filename = 'terr.nc'

'/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/WRF_Radar/rsc/out/preveous_1b/chivo_grid_20181214T0550.nc'
grid_filename = '/top/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/analysis/WRF_Radar/rsc/out/chivo_grid_20181214T0630.nc'


fig = utl.plot_grid_AccumulateTotalPrecip(grid_filename, topo_filename)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/chivo_grid_utl.py:111: UserWarning: The following kwargs were not used by contour: 'animated'
#   linestyles='solid', antialiased=True, animated=True)

# %%
# Create grid

importlib.reload(utl)

filename = '/net/denali/storage/radar/RELAMPAGO/quality_controlled_data/level_1b/2018/12/14/chivo.1b.20181214_053041.REL_PNL360A.nc'

chivo = pyart.io.read(filename)
chivo_grid = utl.grid_radar(chivo)

time_start = netCDF4.num2date(chivo_grid.time['data'][0], chivo_grid.time['units'])
time_text = time_start.strftime('%Y%m%dT%H%M')

chivo_grid_fname = ('./out/chivo_grid_'+ time_text + '.nc')
chivo_grid.write(chivo_grid_fname)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pyart/map/gates_to_grid.py:162: DeprecationWarning: Barnes weighting function is deprecated. Please use Barnes 2 to be consistent with Pauley and Wu 1990.
#   " Pauley and Wu 1990.", DeprecationWarning)

# %%
importlib.reload(utl)

topo_filename = 'terr.nc'
grid_filename = './out/chivo_grid_20181214T0150.nc'

fig = utl.plot_grid_RainRate(grid_filename, topo_filename)
# Out:
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/chivo_grid_utl.py:222: UserWarning: The following kwargs were not used by contour: 'animated'
#   linestyles='solid', antialiased=True, animated=True)

# %%
importlib.reload(utl)

topo_filename = 'terr.nc'
grid_filename = './out/chivo_grid_20181214T0150.nc'

fig = utl.plot_grid_maxRef(grid_filename, topo_filename)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot/chivo_grid_utl.py:334: UserWarning: The following kwargs were not used by contour: 'animated'
#   linestyles='solid', antialiased=True, animated=True)
