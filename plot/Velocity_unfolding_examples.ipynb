# %%
import sys
#sys.path.append('/net/denali/storage2/radar2/tmp/Ivan/CSU/RELAMPAGO/plot')
sys.path.append('/net/nasstore/students/GRAD/ECE/idariash/home/CSU/RELAMPAGO/plot')
import chivo_plot as plot
import importlib
import matplotlib.pyplot as plt
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
importlib.reload(plot)

filename = '/net/denali/storage/projects/RELAMPAGO/quality_controlled_data/level_1a/2018/12/14/chivo.1a.20181214_020012.REL_HYDRO360.nc'

fig = plot.chivo_ppi_1a_vel_unfold(filename, 1)

# %%
importlib.reload(plot)

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_020602.REL_RHI45.nc'

'/net/k2/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_022709.REL_RHI45.nc'


filename_1a = '/net/denali/storage/projects/RELAMPAGO/quality_controlled_data/level_1a/2018/12/14/chivo.1a.20181214_015608.REL_RHI45.nc'
filename_1b = '/net/denali/storage/projects/RELAMPAGO/quality_controlled_data/level_1b.2/2018/12/14/chivo.1b.2.20181214_015608.REL_RHI45.nc'

fig = plot.rhi_drops_1b_4plots_vel(filename_1a, filename_1b, 11)
